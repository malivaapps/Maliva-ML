# %%
import pandas as pd
 # Load data
data = pd.read_csv('data_wisata.csv')
data.head()
# Out:
#             Nama Wisata                                          Deskripsi  \
# 0          Pantai Licin  Pantai Licin terletak di Desa Lebakharjo, Keca...
# 1      Pantai Taman Ayu  Pantai Taman Ayu berlokasi di Desa Sumberbenin...
# 2    Pantai Balekambang  Pantai Balekambang terletak di Desa Srigonco, ...
# 3         Pantai Regent  Pantai Regent berada di Desa Tambakrejo, Kecam...
# 4  Pantai Kondang Merak  Pantai Kondang Merak terletak di Desa Sumberbe...
#
#                 Lokasi / Tempat  \
# 0  Desa Lebakharjo, Ampelgading
# 1      Desa Bandungrejo, Bantur
# 2         Desa Srigonco, Bantur
# 3         Desa Srigonco, Bantur
# 4     Desa Sumberbening, Bantur
#
#                              Fasilitas Yang Tersedia  \
# 0  Tempat parkir, Warung makan, Toilet, Mushola, ...
# 1  Tempat parkir, Warung makan, Toilet, Mushola, ...
# 2  Tempat parkir, Warung makan, Toilet, Mushola, ...
# 3  Tempat parkir, Warung makan, Toilet, Mushola, ...
# 4  Tempat parkir, Warung makan, Toilet, Mushola, ...
#
#                         Aksesibilitas Jenis Wisata      Kategori  \
# 0           makadam, kendaraan roda 2       Pantai  Family, Solo
# 1     makadam, kendaraan roda 2 dan 4       Pantai  Family, Solo
# 2  aspal, kendaraan roda 2 dan 4, bus       Pantai  Family, Solo
# 3  aspal, kendaraan roda 2 dan 4, bus       Pantai  Family, Solo
# 4     makadam, kendaraan roda 2 dan 4       Pantai  Family, Solo
#
#   Child Friendly                                             Alamat  \
# 0            Yes  Area Sawah/Kebun, Lebakharjo, Ampelgading, Kab...
# 1            Yes  Pantai taman ayu, Area Gn., Sidurejo, Gedangan...
# 2            Yes  Jalan Balekambang, Dusun Sumber Jambe, Desa Sr...
# 3            Yes  Jl. Balekambang, Balaikambang, Srigonco, Kec. ...
# 4            Yes  Desa Sumberbening, Kecamatan Bantur, Kabupaten...
#
#                                          Link Alamat  Harga  Rentang Harga  \
# 0  https://www.google.com/maps/place/Pantai+Licin...      0              0
# 1  https://www.google.com/maps/place/Pantai+Taman...  20000              3
# 2  https://www.google.com/maps/place/Balekambang+...  20000              3
# 3  https://www.google.com/maps/place/Pantai+Regen...  15000              2
# 4  https://www.google.com/maps/place/Kondang+Mera...  10000              2
#
#    Rating  latitude   longitude
# 0     4.3 -8.363503  112.946779
# 1     4.1 -8.407483  112.573002
# 2     4.5 -8.403571  112.539371
# 3     4.5 -8.403426  112.545205
# 4     4.4 -8.396575  112.519074

# %%
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Input, Embedding, Flatten, Concatenate
from tensorflow.keras.models import Model
from sklearn.metrics.pairwise import cosine_similarity

# Inisialisasi Firebase Admin SDK
cred = credentials.Certificate('/content/maliva-ml-service.json')
db = firestore.client()

# Load data from Firestore
def load_data_from_firestore():
    # Mengambil data tempat wisata dari Firestore
    docs = db.collection('Destinations').stream()
    data = []

    for doc in docs:
        tempat_wisata = doc.to_dict()
        data.append(tempat_wisata)

    return pd.DataFrame(data)

# Load data
data = load_data_from_firestore()

# Preprocessing
def preprocess_text(text):
    return text.replace(", ", "").replace(" ", "")

data['Aksesibilitas'] = data['Aksesibilitas'].apply(preprocess_text)
data['Fasilitas'] = data['Fasilitas'].apply(preprocess_text)

# Tokenisasi deskripsi
desc_tokenizer = Tokenizer(num_words=10000)
desc_tokenizer.fit_on_texts(data['Deskripsi'])
desc_sequences = desc_tokenizer.texts_to_sequences(data['Deskripsi'])
desc_data = pad_sequences(desc_sequences, maxlen=100)

# Tokenisasi aksesibilitas
acc_tokenizer = Tokenizer(num_words=1000)
acc_tokenizer.fit_on_texts(data['Aksesibilitas'])
acc_sequences = acc_tokenizer.texts_to_sequences(data['Aksesibilitas'])
acc_data = pad_sequences(acc_sequences, maxlen=10)

# Tokenisasi jenis wisata
type_tokenizer = Tokenizer(num_words=100)
type_tokenizer.fit_on_texts(data['Jenis Wisata'])
type_sequences = type_tokenizer.texts_to_sequences(data['Jenis Wisata'])
type_data = pad_sequences(type_sequences, maxlen=5)

# Tokenisasi fasilitas yang tersedia
fac_tokenizer = Tokenizer(num_words=1000)
fac_tokenizer.fit_on_texts(data['Fasilitas'])
fac_sequences = fac_tokenizer.texts_to_sequences(data['Fasilitas'])
fac_data = pad_sequences(fac_sequences, maxlen=20)

# Definisikan input untuk deskripsi
desc_input = Input(shape=(100,), name='desc_input')
desc_embedding = Embedding(input_dim=10000, output_dim=64, input_length=100, name='desc_embedding')(desc_input)
desc_flatten = Flatten()(desc_embedding)

# Definisikan input untuk aksesibilitas
acc_input = Input(shape=(10,), name='acc_input')
acc_embedding = Embedding(input_dim=1000, output_dim=32, input_length=10, name='acc_embedding')(acc_input)
acc_flatten = Flatten()(acc_embedding)

# Definisikan input untuk jenis wisata
type_input = Input(shape=(5,), name='type_input')
type_embedding = Embedding(input_dim=100, output_dim=16, input_length=5, name='type_embedding')(type_input)
type_flatten = Flatten()(type_embedding)

# Definisikan input untuk fasilitas yang tersedia
fac_input = Input(shape=(20,), name='fac_input')
fac_embedding = Embedding(input_dim=1000, output_dim=32, input_length=20, name='fac_embedding')(fac_input)
fac_flatten = Flatten()(fac_embedding)

# Gabungkan semua embedding
merged = Concatenate()([desc_flatten, acc_flatten, type_flatten, fac_flatten])

# Membangun model embedding
embedding_model = Model(inputs=[desc_input, acc_input, type_input, fac_input], outputs=merged)
# Mendapatkan vektor embedding untuk tempat wisata
def get_place_embeddings():
    place_embeddings = []
    docs = db.collection('Destinations').stream()

    for doc in docs:
        tempat_wisata = doc.to_dict()
        desc_seq = desc_tokenizer.texts_to_sequences([tempat_wisata['Deskripsi']])
        acc_seq = acc_tokenizer.texts_to_sequences([tempat_wisata['Aksesibilitas']])
        type_seq = type_tokenizer.texts_to_sequences([tempat_wisata['Jenis Wisata']])
        fac_seq = fac_tokenizer.texts_to_sequences([tempat_wisata['Fasilitas']])

        desc_data = pad_sequences(desc_seq, maxlen=100)
        acc_data = pad_sequences(acc_seq, maxlen=10)
        type_data = pad_sequences(type_seq, maxlen=5)
        fac_data = pad_sequences(fac_seq, maxlen=20)

        place_embedding = embedding_model.predict([desc_data, acc_data, type_data, fac_data])
        place_embeddings.append(place_embedding)

    return place_embeddings

place_embeddings = get_place_embeddings()

# Fungsi untuk mendapatkan riwayat pencarian dari semua pengguna
def get_all_users_search_history_from_firestore():
    # Query ke Firestore untuk mendapatkan riwayat pencarian dari semua pengguna
    docs = db.collection('user_search_history').stream()
    search_terms = []

    for doc in docs:
        search_term = doc.to_dict()['search_term']
        search_terms.append(search_term)

    return search_terms

def get_all_users_preference_vector(input_embedding):
    search_terms = get_all_users_search_history_from_firestore()
    if search_terms:
        search_desc_sequences = desc_tokenizer.texts_to_sequences(search_terms)
        search_desc_data = pad_sequences(search_desc_sequences, maxlen=100)
        search_acc_data = np.zeros((len(search_terms), 10))  # Jika tidak ada data aksesibilitas
        search_type_data = np.zeros((len(search_terms), 5))  # Jika tidak ada data jenis wisata
        search_fac_sequences = fac_tokenizer.texts_to_sequences(search_terms)
        search_fac_data = pad_sequences(search_fac_sequences, maxlen=20)

        search_embeddings = embedding_model.predict([search_desc_data, search_acc_data, search_type_data, search_fac_data])
        averaged_embedding = np.mean(search_embeddings, axis=0, keepdims=True)

        # Padding atau normalisasi dimensi agar cocok dengan input_embedding
        # Misalnya, melakukan padding dengan nilai nol untuk mencocokkan dimensi
        padded_preference_vector = np.zeros_like(input_embedding)  # Dimensi input_embedding
        padded_preference_vector[:, :averaged_embedding.shape[1]] = averaged_embedding

        return padded_preference_vector
    else:
        return np.zeros_like(input_embedding)  # Sesuaikan dengan dimensi input_embedding Anda

# Fungsi utama untuk rekomendasi
def recommend_with_all_users_history(input_name, top_n=10):
    place_index = data[data['Nama Wisata'].str.contains(input_name, case=False)].index
    if len(place_index) > 0:
        place_index = place_index[0]
        input_seq_desc = desc_tokenizer.texts_to_sequences([data.loc[place_index, 'Deskripsi']])
        input_seq_acc = acc_tokenizer.texts_to_sequences([data.loc[place_index, 'Aksesibilitas']])
        input_seq_type = type_tokenizer.texts_to_sequences([data.loc[place_index, 'Jenis Wisata']])
        input_seq_fac = fac_tokenizer.texts_to_sequences([data.loc[place_index, 'Fasilitas']])

        input_data_desc = pad_sequences(input_seq_desc, maxlen=100)
        input_data_acc = pad_sequences(input_seq_acc, maxlen=10)
        input_data_type = pad_sequences(input_seq_type, maxlen=5)
        input_data_fac = pad_sequences(input_seq_fac, maxlen=20)

        input_embedding = embedding_model.predict([input_data_desc, input_data_acc, input_data_type, input_data_fac])
    else:
        input_seq_type = type_tokenizer.texts_to_sequences([input_name])
        input_data_type = pad_sequences(input_seq_type, maxlen=5)
        input_seq_fac = fac_tokenizer.texts_to_sequences([input_name])
        input_data_fac = pad_sequences(input_seq_fac, maxlen=20)

        input_embedding = embedding_model.predict([np.zeros((1, 100)), np.zeros((1, 10)), input_data_type, input_data_fac])

    all_users_preference_vector = get_all_users_preference_vector(input_embedding)

    # Ubah cara Anda menggabungkan input_embedding dan all_users_preference_vector
    combined_embedding = 0.5 * np.squeeze(input_embedding, axis=0) + 0.5 * all_users_preference_vector
    combined_embedding = combined_embedding.reshape(1, -1)  # Pastikan ini 2D

    similarities = cosine_similarity(combined_embedding, np.concatenate(place_embeddings, axis=0))
    similar_indices = similarities.argsort()[0][-top_n-1:][::-1]

    recommendations = data.iloc[similar_indices].to_dict(orient='records')

    return recommendations

# Contoh penggunaan sistem rekomendasi
input_name = 'Kolam Renang'

# Rekomendasi berdasarkan riwayat kolektif
print("Rekomendasi Berdasarkan Riwayat Kolektif:")
recommendations = recommend_with_all_users_history(input_name)
if not recommendations:
    print("Tidak ada rekomendasi yang cocok dengan nama tempat yang Anda cari.")
else:
    for rec in recommendations:
        print(f"Nama Wisata: {rec['Nama Wisata']}")
        print(f"Deskripsi: {rec['Deskripsi']}")
        print(f"Lokasi : {rec['Lokasi ']}")
        print(f"Fasilitas: {rec['Fasilitas']}")
        print(f"Aksesibilitas: {rec['Aksesibilitas']}")
        print(f"Jenis Wisata: {rec['Jenis Wisata']}")
        print(f"Kategori: {rec['Kategori']}")
        print(f"Child Friendly: {rec['Child Friendly']}")
        print(f"Alamat: {rec['Alamat']}")
        print(f"Link Alamat: {rec['Link Alamat']}")
        print(f"Harga: {rec['Harga']}")
        print(f"Rentang Harga: {rec['Rentang Harga']}")
        print(f"Rating: {rec['Rating']}")
        print(f"Latitude: {rec['latitude']}")
        print(f"Longitude: {rec['longitude']}")
        print("\n")
# Out:
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Rekomendasi Berdasarkan Riwayat Kolektif:
# 1/1 [==============================] - 0s 23ms/step
# Nama Wisata: Kolam Renang Sumber Palung
# Deskripsi: Kolam Renang Sumber Palung berlokasi di Desa Sumber Pasir, Kecamatan Pakis, Malang, Jawa Timur. Kolam renang ini memanfaatkan sumber air alami yang jernih dan segar, menawarkan pengalaman berenang yang menyegarkan. Dikelilingi oleh pemandangan alam yang asri, kolam renang ini cocok untuk rekreasi keluarga dan aktivitas olahraga air. Fasilitas di kolam renang ini termasuk area parkir, kamar ganti, dan warung makan.
# Lokasi : {' Tempat': 'Desa Kasri , Bululawang'}
# Fasilitas: Tempatparkirwarungmakantoiletmusholla
# Aksesibilitas: aspalkendaraanroda2&4
# Jenis Wisata: Sumber
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: Jl. Ngurawan No.577, Bendolawang, Pamotan, Kec. Dampit, Kabupaten Malang, Jawa Timur 65181
# Link Alamat: https://www.google.com/maps/place/Kolam+Sumber+Palung/@-8.2038884,112.7518273,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd619049d847c8f:0x7ec2d8bb6e239219!8m2!3d-8.2038884!4d112.7518273!16s%2Fg%2F11bzwq93mc?hl=id&entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 4.2
# Latitude: -8.2038884
# Longitude: 112.7518273
#
#
# Nama Wisata: Sumber Air Krabyakan
# Deskripsi: Sumber Air Krabyakan terletak di Desa Sumber Ngepoh, Kecamatan Lawang, Malang, Jawa Timur. Sumber air ini terkenal dengan kejernihan airnya yang luar biasa dan suasana alam yang asri. Dikelilingi oleh pepohonan dan vegetasi hijau, Sumber Air Krabyakan memberikan suasana yang sejuk dan menenangkan. Tempat ini cocok untuk berenang dan bersantai. Fasilitas yang tersedia meliputi area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Sumberngepoh, Lawang'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollapemandianairpanas
# Aksesibilitas: aspalkendaraanroda2&4
# Jenis Wisata: Sumber
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: 5P4C+V5J, Krajan, SumbernNgepoh, Kec. Lawang, Kabupaten Malang, Jawa Timur 65216
# Link Alamat: https://www.google.com/search?q=Air+Krabyakan&sca_esv=f1470b44e75781e4&sca_upv=1&rlz=1C1UEAD_enID951ID951&ei=cSJXZpHSE7G74-EP_oSqyAY&ved=0ahUKEwjRzraK8bKGAxWx3TgGHX6CCmkQ4dUDCBA&uact=5&oq=Air+Krabyakan&gs_lp=-6BgQIARgHugYECAIYCpIHAzEuMqAHqwo&sclient=gws-wiz-serp
# Harga: 75000
# Rentang Harga: 6
# Rating: 4.3
# Latitude: -7.8427903
# Longitude: 112.7204015
#
#
# Nama Wisata: Coban Tanaka
# Deskripsi: Coban Tanaka berlokasi di Desa Sumber Brantas, Kecamatan Bumiaji, Kota Batu, Malang, Jawa Timur. Air terjun ini menawarkan pemandangan yang indah dengan aliran air yang deras dan segar serta dikelilingi oleh hutan yang hijau. Coban Tanaka memberikan suasana yang tenang dan menyegarkan, cocok untuk trekking dan fotografi alam. Fasilitas di Coban Tanaka termasuk area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Bangelan, Wonosari'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollaareapiknikpemandianairterjun
# Aksesibilitas: aspalcorkendaraanroda2dan4
# Jenis Wisata: Air Terjun
# Kategori: Solo
# Child Friendly: No
# Alamat: WF7X+X6X, Unnamed Road, Arjomulyo, Bangelan, Kec. Wonosari, Kabupaten Malang, Jawa Timur 65164
# Link Alamat: https://www.google.com/maps/place/Wisata+Umbulan+Tanaka/@-8.0849644,112.495504,17z/data=!4m10!1m2!2m1!1sCoban+Tanaka+!3m6!1s0x2e789ba32f4ae5b3:0x370859eb1bd21d56!8m2!3d-8.0850019!4d112.4980953!15sCgxDb2JhbiBUYW5ha2GSARJ0b3VyaXN0X2F0dHJhY3Rpb27gAQA!16s%2Fg%2F11lwdhxz13?entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 4.5
# Latitude: -8.0849644
# Longitude: 112.495504
#
#
# Nama Wisata: Kebun Bundu
# Deskripsi: Kebun Bundu terletak di Desa Sidomulyo, Kecamatan Batu, Kota Batu, Malang, Jawa Timur. Kebun ini menawarkan pemandangan yang indah dengan berbagai tanaman hias dan bunga-bunga yang ditanam dengan rapi. Tempat ini cocok untuk rekreasi keluarga, berfoto, dan menikmati keindahan alam. Fasilitas di Kebun Bundu termasuk area parkir, taman bermain, dan warung makan.
# Lokasi : {' Tempat': 'Desa Purwoharjo, Ampelgading'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollaareabermainanakflyingfox
# Aksesibilitas: JalanMakadam&CorRoda2
# Jenis Wisata: kebun
# Kategori: Friends, Solo
# Child Friendly: No
# Alamat: PWM3+2MJ, Area Sawah/Kebun, Purwoharjo, Kec. Ampelgading, Kabupaten Malang, Jawa Timur 65183
# Link Alamat: https://www.google.com/maps/place/Puncak+Bundu/@-8.2654713,112.9001496,17z/data=!4m10!1m2!2m1!1sKebun+Bundu!3m6!1s0x2dd611c3e618a0db:0x732417f905b4c3e9!8m2!3d-8.2674181!4d112.9041506!15sCgtLZWJ1biBCdW5kdZIBEnRvdXJpc3RfYXR0cmFjdGlvbuABAA!16s%2Fg%2F11jp0_5yws?entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 4.4
# Latitude: -8.2654713
# Longitude: 112.9001496
#
#
# Nama Wisata: Sungai Rafting Kasembon
# Deskripsi: Sungai Rafting Kasembon berlokasi di Desa Bayem, Kecamatan Kasembon, Malang, Jawa Timur. Sungai ini terkenal sebagai tempat arung jeram dengan aliran air yang deras dan menantang. Dikelilingi oleh pemandangan alam yang indah, Sungai Rafting Kasembon menawarkan pengalaman petualangan yang seru dan mendebarkan. Fasilitas di lokasi ini meliputi area parkir, tempat penyewaan peralatan rafting, dan warung makan.
# Lokasi : {' Tempat': 'Desa Bayem, Kasembon'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollapenyewaanalatrafting
# Aksesibilitas: aspalkendaraanroda2
# Jenis Wisata: Sungai
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: 58W6+6WW, Desa, RT.05/RW.12, Bayem, Kec. Kasembon, Kabupaten Malang, Jawa Timur 65393
# Link Alamat: https://www.google.com/search?q=Rafting+Kasembon&sca_esv=f1470b44e75781e4&sca_upv=1&rlz=1C1UEAD_enID951ID951&ei=bCJXZqC5HaLA4-EP8-uz0As&ved=0ahUKEwign4-I8bKGAxUi4DgGHfP1DLoQ4dUDCBA&uact=5&oq=Rafting+Kasembon&gs_lp=Egxnd3Mtd2l6LXNlcnAiEFJhZnRpbmcgS2FzZW1ib24yBRAAGIAEMggQABgHGB4YDzIGEAAYBxgeMgYQABgHGB4yBhAAGAcYHjIGEAAYBxgeMgYQABgHGB4yBBAAGB4yBBAAGB4yBBAAGB5I9wdQhgNYxQRwAXgBkAEAmAFkoAG-AaoBAzEuMbgBA8gBAPgBAZgCA6AC0QHCAgoQABiwAxjWBBhHwgIHEAAYgAQYDcICBhAAGA0YHsICCBAAGA0YHhgPwgIKEAAYBRgNGB4YD8ICCBAAGAUYDRgemAMAiAYBkAYEkgcDMi4xoAfADQ&sclient=gws-wiz-serp&lqi=ChBSYWZ0aW5nIEthc2VtYm9uSOCEw5a8gYCACFocEAAYABgBIhByYWZ0aW5nIGthc2VtYm9uMgJpZJIBB3JhZnRpbmeqAUYQASoLIgdyYWZ0aW5nKCYyHxABIhtabysi0HPhrjUb2ZS5s4PRxr-v7ZwIoKLd7RUyFBACIhByYWZ0aW5nIGthc2VtYm9u#rlimm=12118140195999641780
# Harga: 120000
# Rentang Harga: 7
# Rating: 4.2
# Latitude: -7.9489949
# Longitude: 111.9922306
#
#
# Nama Wisata: Waduk Selorejo
# Deskripsi: Waduk Selorejo terletak di Desa Selorejo, Kecamatan Ngantang, Malang, Jawa Timur. Waduk ini menawarkan pemandangan yang indah dengan air yang tenang dan dikelilingi oleh perbukitan hijau serta pepohonan. Tempat ini cocok untuk berbagai aktivitas seperti memancing, berperahu, dan piknik bersama keluarga. Fasilitas di Waduk Selorejo termasuk area parkir, tempat penyewaan perahu, dan warung makan.
# Lokasi : {' Tempat': 'Desa Mulyorejo, Ngantang'}
# Fasilitas: TempatparkirwarungmakantoiletmushollaHotelTamanRekreasiPemancinganIkan
# Aksesibilitas: aspalkendaraanroda2danroda4bus
# Jenis Wisata: Waduk
# Kategori: Friends, Solo
# Child Friendly: No
# Alamat: Sambirejo, Pandansari, Ngantang, Kabupaten Malang, East Java
# Link Alamat: https://www.google.com/maps/place/Waduk+Selorejo/@-7.8652563,112.3508113,15z/data=!3m1!4b1!4m6!3m5!1s0x2e7889c32f127eaf:0x7b9c3949e9cc22dc!8m2!3d-7.8652778!4d112.3611111!16s%2Fg%2F11b_2vxzq3?entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 4.3
# Latitude: -7.8652563
# Longitude: 112.3508113
#
#
# Nama Wisata: Sumber Waras
# Deskripsi: Sumber Waras terletak di Desa Petungsewu, Kecamatan Dau, Malang, Jawa Timur. Sumber air ini dikenal dengan kejernihan airnya yang alami dan suasana alam yang sejuk. Dikelilingi oleh pepohonan dan vegetasi hijau, Sumber Waras memberikan suasana yang tenang dan menenangkan. Tempat ini cocok untuk berenang dan bersantai. Fasilitas yang tersedia meliputi area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Babadan, Lawang'}
# Fasilitas: Tempatparkirwarungmakantoiletmusholla,
# Aksesibilitas: aspalkendaraanroda2&4
# Jenis Wisata: Sumber
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: 5P43+P59, Jl. Sumber Waras 2, Lawang, Kalirejo, Kec. Lawang, Kabupaten Malang, Jawa Timur 65216
# Link Alamat: https://www.google.com/maps/place/Pemandian+Sumber+Waras/@-8.1744427,114.3011362,15z/data=!4m15!1m7!3m6!1s0x2dd14f68c1870ead:0xb5ca091b2f243c7!2sPemandian+Sumber+Waras!8m2!3d-8.1777956!4d114.3018678!16s%2Fg%2F11f5_j0r9t!3m6!1s0x2dd14f68c1870ead:0xb5ca091b2f243c7!8m2!3d-8.1777956!4d114.3018678!15sChZwZW1hbmRpYW4gc3VtYmVyIHdhcmFzkgESdG91cmlzdF9hdHRyYWN0aW9u4AEA!16s%2Fg%2F11f5_j0r9t?entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 5.0
# Latitude: -8.1744427
# Longitude: 114.3011362
#
#
# Nama Wisata: Sumber Ranu Sosro
# Deskripsi: Sumber Ranu Sosro terletak di Desa Ngajum, Kecamatan Ngajum, Malang, Jawa Timur. Sumber air alami ini dikenal dengan keindahan airnya yang jernih dan segar. Dikelilingi oleh vegetasi hijau dan pepohonan, Sumber Ranu Sosro menciptakan suasana yang sejuk dan alami. Tempat ini cocok untuk berenang, berendam, dan piknik bersama keluarga. Fasilitas yang tersedia meliputi area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Tirtomoyo, Ampelgading'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollapemandianairpanasperahuwisatapenginapan
# Aksesibilitas: aspalkendaraanroda2&4
# Jenis Wisata: Sumber
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: QVCM+8Q5, Sumbersewu, Tirtomoyo, Kec. Ampelgading, Kabupaten Malang, Jawa Timur 65183
# Link Alamat: https://www.google.com/maps/place/Ranu+Sosro+%EA%A6%AB%EA%A6%A4%EA%A6%B8%EA%A6%B1%EA%A6%B1%EA%A6%BF/@-8.2292383,112.8844729,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd617eabe7058d7:0xce8ea1685666e!8m2!3d-8.2292383!4d112.8844729!16s%2Fg%2F11hzw3400l?hl=id&entry=ttu
# Harga: 15000
# Rentang Harga: 2
# Rating: 4.4
# Latitude: -8.2292383
# Longitude: 112.8844729
#
#
# Nama Wisata: Sumber Rafting Ndayung
# Deskripsi: Sumber Rafting Ndayung berlokasi di Desa Gubugklakah, Kecamatan Poncokusumo, Malang, Jawa Timur. Tempat ini terkenal sebagai lokasi arung jeram dengan aliran sungai yang deras dan menantang, cocok untuk para penggemar olahraga ekstrem. Dikelilingi oleh pemandangan alam yang indah, Sumber Rafting Ndayung menawarkan pengalaman petualangan yang seru dan mendebarkan. Fasilitas di lokasi ini meliputi area parkir, tempat penyewaan peralatan rafting, dan warung makan.
# Lokasi : {' Tempat': 'Desa Gubugklakah, Poncokusumo'}
# Fasilitas: Tempatparkirwarungmakantoiletmushollapenyewaanalatraftingpemandurafting
# Aksesibilitas: aspalkendaraanroda2&4
# Jenis Wisata: Sumber
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: Jl. Raya Gubugklakah, Gubukklakah, Gubugklakah, Kec. Poncokusumo, Kabupaten Malang, Jawa Timur 65157
# Link Alamat: https://www.google.com/search?q=rafting+ndayung+gubuglakah+poncokusumo+&sca_esv=f1470b44e75781e4&sca_upv=1&rlz=1C1UEAD_enID951ID951&ei=ZSVXZqKmBvOx4-EPp6CXoAw&ved=0ahUKEwji7Ofy87KGAxXz2DgGHSfQBcQQ4dUDCBA&uact=5&oq=rafting+ndayung+gubuglakah+poncokusumo+&gs_lp=Egxnd3Mtd2l6LXNlcnAiJ3JhZnRpbmcgbmRheXVuZyBndWJ1Z2xha2FoIHBvbmNva3VzdW1vIDIHECEYoAEYCkjdLVD_AlifLXACeACQAQCYAaEBoAGpFaoBBDUuMTm4AQPIAQD4AQGYAhqgAvwVwgIJEAAYsAMYCBgewgILEAAYsAMYCBgeGA_CAgsQABiABBiwAxiiBMICBhAAGBYYHsICCBAAGBYYHhgPwgIIEAAYgAQYogTCAgUQIRigAcICBBAhGBWYAwCIBgGQBgeSBwQ1LjIxoAfCZQ&sclient=gws-wiz-serp&lqi=CidyYWZ0aW5nIG5kYXl1bmcgZ3VidWdrbGFrYWggcG9uY29rdXN1bW9I_t2K9_#rlimm=10349861093891935059
# Harga: 100000
# Rentang Harga: 7
# Rating: 4.5
# Latitude: -8.0140726
# Longitude: 112.8507854
#
#
# Nama Wisata: Pantai Modangan
# Deskripsi: Pantai Modangan berlokasi di Desa Sumberoto, Kecamatan Donomulyo, Malang, Jawa Timur. Pantai ini memiliki pasir putih yang luas dan air laut yang biru kehijauan, menciptakan pemandangan yang sangat mempesona. Ombak di pantai ini cukup besar, sehingga cocok untuk surfing. Pantai Modangan juga terkenal dengan pemandangan sunset yang indah. Fasilitas di pantai ini meliputi area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Sumberroto, Donomulyo'}
# Fasilitas: TempatparkirWarungmakanToiletMusholaPenginapanPenyewaanperahuKegiatanwisataair
# Aksesibilitas: makadamkendaraanroda2dan4
# Jenis Wisata: Pantai
# Kategori: Family, Solo
# Child Friendly: Yes
# Alamat: Sumberrejo, Sumberoto, Donomulyo, Kabupaten Malang, East Java 65167
# Link Alamat: https://www.google.com/maps/place/Modangan+Beach/@-8.3488685,112.3590898,15z/data=!3m1!4b1!4m6!3m5!1s0x2e78ba9555555555:0x3af2cf1ed2b6dcf!8m2!3d-8.3488687!4d112.3590898!16s%2Fg%2F1q61ccf63?entry=ttu
# Harga: 20000
# Rentang Harga: 3
# Rating: 4.3
# Latitude: -8.3488685
# Longitude: 112.3590898
#
#
# Nama Wisata: Coban Barnawi
# Deskripsi: Coban Barnawi berlokasi di Desa Sukodono, Kecamatan Dampit, Malang, Jawa Timur. Air terjun ini menawarkan keindahan alam yang mempesona dengan aliran air yang jernih dan segar. Dikelilingi oleh hutan dan vegetasi hijau, Coban Barnawi memberikan suasana yang tenang dan menenangkan. Tempat ini cocok untuk trekking ringan dan piknik. Fasilitas yang tersedia meliputi area parkir dan warung makan.
# Lokasi : {' Tempat': 'Desa Sukopuro, Jabung'}
# Fasilitas: Tempatparkirtoiletwarungmakangazebomusholla
# Aksesibilitas: makadamkendaraanroda2dan4
# Jenis Wisata: Air Terjun
# Kategori: Solo
# Child Friendly: No
# Alamat: desa, Pandan Rejo Cincing No.dusun, Dusun Krajan, Sukopuro, Kec. Jabung, Kabupaten Malang, Jawa Timur 65155
# Link Alamat: https://www.google.com/maps/place/Coban+Barnawi+%EA%A6%95%EA%A6%BA%EA%A6%B4%EA%A6%A7%EA%A6%A4%EA%A7%80%EA%A6%A7%EA%A6%82%EA%A6%A4%EA%A7%80%EA%A6%A4%EA%A6%AE%EA%A6%B6/@-7.9750419,112.8094921,17z/data=!3m1!4b1!4m6!3m5!1s0x2dd6301e409be4cd:0xaa3096071de051ba!8m2!3d-7.9750472!4d112.812067!16s%2Fg%2F11c5_n2bk7?entry=ttu
# Harga: 10000
# Rentang Harga: 2
# Rating: 4.0
# Latitude: -7.9750419
# Longitude: 112.8094921

# %%
import pickle

# Simpan model dan tokenizers
def save_model_and_tokenizers():
    # Simpan model ke dalam file
    embedding_model.save('embedding_model.h5')

    # Simpan tokenizer ke dalam file menggunakan pickle
    with open('desc_tokenizer.pkl', 'wb') as f:
        pickle.dump(desc_tokenizer, f)
    with open('acc_tokenizer.pkl', 'wb') as f:
        pickle.dump(acc_tokenizer, f)
    with open('type_tokenizer.pkl', 'wb') as f:
        pickle.dump(type_tokenizer, f)
    with open('fac_tokenizer.pkl', 'wb') as f:
        pickle.dump(fac_tokenizer, f)

# Panggil fungsi untuk menyimpan model dan tokenizer
save_model_and_tokenizers()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
  # Simpan model ke dalam format .keras
  #embedding_model.save('model_rekomendasi.keras')
  # Memuat model dari file .keras
  #loaded_model = tf.keras.models.load_model('model_rekomendasi.keras')
  # Contoh: Kompilasi model setelah memuatnya
  #loaded_model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# %%
#!pip install tensorflowjs

# %%
import tensorflowjs as tfjs

# Tentukan path untuk model Keras dan model TensorFlow.js yang dihasilkan
#keras_model_path = 'model_rekomendasi.keras'
#tfjs_target_dir = '/content/tfjs_model/'

# Konversi model ke format TensorFlow.js
#tfjs.converters.save_keras_model(embedding_model, tfjs_target_dir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-aa41e6769d4d> in <cell line: 1>()
# ----> 1 import tensorflowjs as tfjs
#       2
#       3 # Tentukan path untuk model Keras dan model TensorFlow.js yang dihasilkan
#       4 #keras_model_path = 'model_rekomendasi.keras'
#       5 #tfjs_target_dir = '/content/tfjs_model/'
#
# ModuleNotFoundError: No module named 'tensorflowjs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Kompresi direktori TensorFlow.js menjadi zip file
#import shutil

#shutil.make_archive('/content/tfjs_model', 'zip', tfjs_target_dir)

# Unduh zip file
#from google.colab import files

#files.download('/content/tfjs_model.zip')

# %%
import tensorflow as tf
import tensorflowjs as tfjs
import shutil
from google.colab import files
import zipfile
import os

# Load model dari TensorFlow
embedding_model = tf.keras.applications.MobileNetV2()

# Simpan model sebagai SavedModel
saved_model_dir = 'rekomendasi_model'
tf.saved_model.save(model, saved_model_dir)

# Konversi model ke TensorFlow.js format
output_tfjs_path = 'tfjs_model'
# !tensorflowjs_converter --input_format=tf_saved_model --output_format=tfjs_graph_model \
                        --signature_name=serving_default --saved_model_tags=serve \
                        {saved_model_dir} {output_tfjs_path}

# Fungsi untuk membuat file zip
def zip_dir(directory, zip_filename):
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(directory):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), os.path.join(directory, '..')))

# Kompres direktori tfjs_model menjadi zip
zip_filename = 'tfjs_model.zip'
zip_dir(output_tfjs_path, zip_filename)

# Unduh file zip ke perangkat lokal
files.download(zip_filename)
